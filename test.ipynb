# %%
from wall_removal import process_folder_json_files

process_folder_json_files("dataset/rplan_json_remapped", "processed")
# Out:
# Found 76058 JSON files to process
# Processed dataset/rplan_json_remapped\0.json -> processed\0.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\1.json -> processed\1.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10.json -> processed\10.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\100.json -> processed\100.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\1000.json -> processed\1000.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10000.json -> processed\10000.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10001.json -> processed\10001.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10002.json -> processed\10002.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10003.json -> processed\10003.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10004.json -> processed\10004.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10005.json -> processed\10005.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10006.json -> processed\10006.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10007.json -> processed\10007.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10008.json -> processed\10008.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10009.json -> processed\10009.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\1001.json -> processed\1001.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10010.json -> processed\10010.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10011.json -> processed\10011.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10012.json -> processed\10012.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10013.json -> processed\10013.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10014.json -> processed\10014.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10015.json -> processed\10015.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10016.json -> processed\10016.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10017.json -> processed\10017.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10018.json -> processed\10018.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10019.json -> processed\10019.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\1002.json -> processed\1002.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10020.json -> processed\10020.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10021.json -> processed\10021.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10022.json -> processed\10022.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10023.json -> processed\10023.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10024.json -> processed\10024.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10025.json -> processed\10025.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10026.json -> processed\10026.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10027.json -> processed\10027.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10028.json -> processed\10028.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10029.json -> processed\10029.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\1003.json -> processed\1003.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10030.json -> processed\10030.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10031.json -> processed\10031.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10032.json -> processed\10032.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10033.json -> processed\10033.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10034.json -> processed\10034.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10035.json -> processed\10035.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10036.json -> processed\10036.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10037.json -> processed\10037.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10038.json -> processed\10038.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10039.json -> processed\10039.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\1004.json -> processed\1004.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10040.json -> processed\10040.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10041.json -> processed\10041.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10042.json -> processed\10042.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10043.json -> processed\10043.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10044.json -> processed\10044.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10045.json -> processed\10045.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10046.json -> processed\10046.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10047.json -> processed\10047.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10048.json -> processed\10048.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10049.json -> processed\10049.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\1005.json -> processed\1005.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10050.json -> processed\10050.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10051.json -> processed\10051.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10052.json -> processed\10052.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10053.json -> processed\10053.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10054.json -> processed\10054.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10055.json -> processed\10055.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10056.json -> processed\10056.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10057.json -> processed\10057.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10058.json -> processed\10058.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10059.json -> processed\10059.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\1006.json -> processed\1006.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10060.json -> processed\10060.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10061.json -> processed\10061.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10063.json -> processed\10063.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10064.json -> processed\10064.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10065.json -> processed\10065.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10066.json -> processed\10066.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10067.json -> processed\10067.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10068.json -> processed\10068.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10069.json -> processed\10069.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\1007.json -> processed\1007.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10070.json -> processed\10070.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10071.json -> processed\10071.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10072.json -> processed\10072.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10073.json -> processed\10073.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10074.json -> processed\10074.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10075.json -> processed\10075.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10076.json -> processed\10076.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10077.json -> processed\10077.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10078.json -> processed\10078.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10079.json -> processed\10079.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\1008.json -> processed\1008.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10080.json -> processed\10080.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10081.json -> processed\10081.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10082.json -> processed\10082.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10084.json -> processed\10084.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10085.json -> processed\10085.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10086.json -> processed\10086.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10087.json -> processed\10087.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10088.json -> processed\10088.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10089.json -> processed\10089.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10090.json -> processed\10090.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10091.json -> processed\10091.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10092.json -> processed\10092.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10093.json -> processed\10093.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10094.json -> processed\10094.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10095.json -> processed\10095.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10096.json -> processed\10096.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10097.json -> processed\10097.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10098.json -> processed\10098.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10099.json -> processed\10099.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\101.json -> processed\101.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\
json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10833.json -> processed\10833.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10834.json -> processed\10834.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10835.json -> processed\10835.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10836.json -> processed\10836.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10837.json -> processed\10837.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10838.json -> processed\10838.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10839.json -> processed\10839.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\1084.json -> processed\1084.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10840.json -> processed\10840.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10841.json -> processed\10841.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10842.json -> processed\10842.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10843.json -> processed\10843.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10844.json -> processed\10844.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10845.json -> processed\10845.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10846.json -> processed\10846.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10847.json -> processed\10847.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10848.json -> processed\10848.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10849.json -> processed\10849.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\1085.json -> processed\1085.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10850.json -> processed\10850.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10851.json -> processed\10851.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10852.json -> processed\10852.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10853.json -> processed\10853.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10854.json -> processed\10854.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10855.json -> processed\10855.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10857.json -> processed\10857.json (added 1 boundary polygons)
# Processed dataset/rplan_json_remapped\10858.json -> processed\10858.json (added 1 boundary polygons)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from wall_removal import process_folder_json_files
# ----> 3 process_folder_json_files("dataset/rplan_json_remapped", "processed")
#
# File c:\Users\Adeer\github\house_diffusion\wall_removal.py:432, in process_folder_json_files(input_folder, output_folder)
#     428     filename = os.path.basename(json_file)
#     430     output_path = os.path.join(output_folder, f"{filename}")
# --> 432     if process_json_file_to_json(json_file, output_path):
#     433         success_count += 1
#     435 print(f"Successfully processed {success_count}/{len(json_files)} files")
#
# File c:\Users\Adeer\github\house_diffusion\wall_removal.py:370, in process_json_file_to_json(input_json_path, output_json_path)
#     368 def process_json_file_to_json(input_json_path, output_json_path):
#     369     try:
# --> 370         room_polygons_list, room_types_list, _ = remove_walls(input_json_path)
#     372         # Align polygons to close gaps between adjacent rooms.
#     373         aligned_polygons = align_adjacent_boundaries(room_polygons_list)
#
# File c:\Users\Adeer\github\house_diffusion\wall_removal.py:308, in remove_walls(json_file_path, output_size)
#     305 filtered_fp_eds[:, 2:] -= shift
#     307 # Use exact build_graph
# --> 308 nodes, triples, rms_masks = build_graph_exact(filtered_rms_type, filtered_fp_eds, filtered_eds_to_rms, out_size=64)
#     309 # Extract polygons from masks - treat all room types uniformly
#     310 room_polygons = []
#
# File c:\Users\Adeer\github\house_diffusion\wall_removal.py:108, in build_graph_exact(rms_type, fp_eds, eds_to_rms, out_size)
#     105         print("Empty room")
#     106         exit(0)
# --> 108 rm_im = rm_im.resize((out_size, out_size))
#     109 rm_arr = np.array(rm_im)
#     110 inds = np.where(rm_arr>0)
#
# File c:\Users\Adeer\.conda\envs\wire\Lib\site-packages\PIL\Image.py:2365, in Image.resize(self, size, resample, box, reducing_gap)
#    2353         self = (
#    2354             self.reduce(factor, box=reduce_box)
#    2355             if callable(self.reduce)
#    2356             else Image.reduce(self, factor, box=reduce_box)
#    2357         )
#    2358         box = (
#    2359             (box[0] - reduce_box[0]) / factor_x,
#    2360             (box[1] - reduce_box[1]) / factor_y,
#    2361             (box[2] - reduce_box[0]) / factor_x,
#    2362             (box[3] - reduce_box[1]) / factor_y,
#    2363         )
# -> 2365 return self._new(self.im.resize(size, resample, box))
#
# KeyboardInterrupt:

# %%
from visualization import visualize_floorplan

selected_files = visualize_floorplan("processed")
# Out:
# Visualizing 9 randomly selected files from processed
