# %%
from wall_removal import process_folder_json_files

process_folder_json_files("dataset/rplan_json_remapped", "processed", boundary_offset=0.002)
# Out:
# Found 76058 JSON files to process
# Processed dataset/rplan_json_remapped\0.json -> processed\0.json (added 6 boundary polygons)
# Processed dataset/rplan_json_remapped\1.json -> processed\1.json (added 3 boundary polygons)
# Processed dataset/rplan_json_remapped\10.json -> processed\10.json (added 3 boundary polygons)
# Processed dataset/rplan_json_remapped\100.json -> processed\100.json (added 12 boundary polygons)
# Processed dataset/rplan_json_remapped\1000.json -> processed\1000.json (added 3 boundary polygons)
# Processed dataset/rplan_json_remapped\10000.json -> processed\10000.json (added 4 boundary polygons)
# Processed dataset/rplan_json_remapped\10001.json -> processed\10001.json (added 4 boundary polygons)
# Processed dataset/rplan_json_remapped\10002.json -> processed\10002.json (added 5 boundary polygons)
# Processed dataset/rplan_json_remapped\10003.json -> processed\10003.json (added 3 boundary polygons)
# ...

# %%
from visualization import visualize_floorplan

selected_files = visualize_floorplan("processed")
# Out:
# Visualizing 9 randomly selected files from processed
